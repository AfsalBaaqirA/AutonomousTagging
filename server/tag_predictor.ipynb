# %%
import pandas as pd
import numpy as np


import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import seaborn as sns

import warnings

import pickle
import time

import re
from bs4 import BeautifulSoup
import nltk
from nltk.tokenize import ToktokTokenizer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
from string import punctuation

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit
from sklearn.dummy import DummyClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import model_selection
from sklearn.metrics import make_scorer
from sklearn.metrics import confusion_matrix
from sklearn.metrics import hamming_loss
from sklearn.cluster import KMeans


import logging

from scipy.sparse import hstack

# %%
# Setting a random seed in order to keep the same random results each time I run the notebook
np.random.seed(seed=11)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
df = pd.read_csv("Questions.csv", encoding="ISO-8859-1")
df.head()
# Out:
#     Id  OwnerUserId          CreationDate            ClosedDate  Score  \
# 0   80         26.0  2008-08-01T13:57:07Z                   NaN     26
# 1   90         58.0  2008-08-01T14:41:24Z  2012-12-26T03:45:49Z    144
# 2  120         83.0  2008-08-01T15:50:08Z                   NaN     21
# 3  180    2089740.0  2008-08-01T18:42:19Z                   NaN     53
# 4  260         91.0  2008-08-01T23:22:08Z                   NaN     49
#
#                                                Title  \
# 0  SQLStatement.execute() - multiple queries in o...
# 1  Good branching and merging tutorials for Torto...
# 2                                  ASP.NET Site Maps
# 3                 Function for creating color wheels
# 4  Adding scripting functionality to .NET applica...
#
#                                                 Body
# 0  <p>I've written a database generation script i...
# 1  <p>Are there any really good tutorials explain...
# 2  <p>Has anyone got experience creating <strong>...
# 3  <p>This is something I've pseudo-solved many t...
# 4  <p>I have a little game written in C#. It uses...

# %%
tags = pd.read_csv("Tags.csv", encoding="ISO-8859-1", dtype={'Tag': str})
tags.head()
# Out:
#    Id             Tag
# 0  80            flex
# 1  80  actionscript-3
# 2  80             air
# 3  90             svn
# 4  90     tortoisesvn

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1264216 entries, 0 to 1264215
# Data columns (total 7 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   Id            1264216 non-null  int64
#  1   OwnerUserId   1249762 non-null  float64
#  2   CreationDate  1264216 non-null  object
#  3   ClosedDate    55959 non-null    object
#  4   Score         1264216 non-null  int64
#  5   Title         1264216 non-null  object
#  6   Body          1264216 non-null  object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 67.5+ MB

# %%
tags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3750994 entries, 0 to 3750993
# Data columns (total 2 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Id      int64
#  1   Tag     object
# dtypes: int64(1), object(1)
# memory usage: 57.2+ MB

# %%
tags['Tag'] = tags['Tag'].astype(str)

# %%
grouped_tags = tags.groupby("Id")['Tag'].apply(lambda tags: ' '.join(tags))

# %%
grouped_tags.head(5)
# Out:
# Id
# 80                            flex actionscript-3 air
# 90       svn tortoisesvn branch branching-and-merging
# 120                               sql asp.net sitemap
# 180    algorithm language-agnostic colors color-space
# 260           c# .net scripting compiler-construction
# Name: Tag, dtype: object

# %%
grouped_tags.reset_index()
# Out:
#                Id                                             Tag
# 0              80                         flex actionscript-3 air
# 1              90    svn tortoisesvn branch branching-and-merging
# 2             120                             sql asp.net sitemap
# 3             180  algorithm language-agnostic colors color-space
# 4             260         c# .net scripting compiler-construction
# ...           ...                                             ...
# 1264211  40143210                                   php .htaccess
# 1264212  40143300                                 google-bigquery
# 1264213  40143340                          android android-studio
# 1264214  40143360                               javascript vue.js
# 1264215  40143380                                 npm mocha babel
#
# [1264216 rows x 2 columns]

# %%
grouped_tags_final = pd.DataFrame({'Id':grouped_tags.index, 'Tags':grouped_tags.values})

# %%
grouped_tags_final.head(5)
# Out:
#     Id                                            Tags
# 0   80                         flex actionscript-3 air
# 1   90    svn tortoisesvn branch branching-and-merging
# 2  120                             sql asp.net sitemap
# 3  180  algorithm language-agnostic colors color-space
# 4  260         c# .net scripting compiler-construction

# %%
df.drop(columns=['OwnerUserId', 'CreationDate', 'ClosedDate'], inplace=True)

# %%
df = df.merge(grouped_tags_final, on='Id')

# %%
df.head(5)
# Out:
#     Id  Score                                              Title  \
# 0   80     26  SQLStatement.execute() - multiple queries in o...
# 1   90    144  Good branching and merging tutorials for Torto...
# 2  120     21                                  ASP.NET Site Maps
# 3  180     53                 Function for creating color wheels
# 4  260     49  Adding scripting functionality to .NET applica...
#
#                                                 Body  \
# 0  <p>I've written a database generation script i...
# 1  <p>Are there any really good tutorials explain...
# 2  <p>Has anyone got experience creating <strong>...
# 3  <p>This is something I've pseudo-solved many t...
# 4  <p>I have a little game written in C#. It uses...
#
#                                              Tags
# 0                         flex actionscript-3 air
# 1    svn tortoisesvn branch branching-and-merging
# 2                             sql asp.net sitemap
# 3  algorithm language-agnostic colors color-space
# 4         c# .net scripting compiler-construction

# %%
new_df = df[df['Score']>5]

# %%
plt.figure(figsize=(5, 5))
new_df.isnull().mean(axis=0).plot.barh()
plt.title("Ratio of missing values per columns")
# Out:
# Text(0.5, 1.0, 'Ratio of missing values per columns')

# %%
print('Dupplicate entries: {}'.format(new_df.duplicated().sum()))
new_df.drop_duplicates(inplace = True)
# Out:
# Dupplicate entries: 0
# <ipython-input-20-715eaf675cdb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.drop_duplicates(inplace = True)

# %%
new_df.drop(columns=['Id', 'Score'], inplace=True)
# Out:
# <ipython-input-21-9acd0740b2ec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.drop(columns=['Id', 'Score'], inplace=True)

# %%
new_df.head(5)
# Out:
#                                                Title  \
# 0  SQLStatement.execute() - multiple queries in o...
# 1  Good branching and merging tutorials for Torto...
# 2                                  ASP.NET Site Maps
# 3                 Function for creating color wheels
# 4  Adding scripting functionality to .NET applica...
#
#                                                 Body  \
# 0  <p>I've written a database generation script i...
# 1  <p>Are there any really good tutorials explain...
# 2  <p>Has anyone got experience creating <strong>...
# 3  <p>This is something I've pseudo-solved many t...
# 4  <p>I have a little game written in C#. It uses...
#
#                                              Tags
# 0                         flex actionscript-3 air
# 1    svn tortoisesvn branch branching-and-merging
# 2                             sql asp.net sitemap
# 3  algorithm language-agnostic colors color-space
# 4         c# .net scripting compiler-construction

# %%
new_df['Tags'] = new_df['Tags'].apply(lambda x: x.split())
# Out:
# <ipython-input-23-b60d69d642f8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Tags'] = new_df['Tags'].apply(lambda x: x.split())

# %%
all_tags = [item for sublist in new_df['Tags'].values for item in sublist]

# %%
len(all_tags)
# Out:
# 224129

# %%
my_set = set(all_tags)
unique_tags = list(my_set)
len(unique_tags)
# Out:
# 14883

# %%
flat_list = [item for sublist in new_df['Tags'].values for item in sublist]

keywords = nltk.FreqDist(flat_list)

keywords = nltk.FreqDist(keywords)

frequencies_words = keywords.most_common(100)
tags_features = [word[0] for word in frequencies_words]

# %%
tags_features
# Out:
# ['c#',
#  'java',
#  'javascript',
#  'android',
#  'python',
#  'c++',
#  'php',
#  'jquery',
#  '.net',
#  'ios',
#  'html',
#  'css',
#  'c',
#  'iphone',
#  'objective-c',
#  'ruby-on-rails',
#  'sql',
#  'asp.net',
#  'mysql',
#  'ruby',
#  'r',
#  'git',
#  'asp.net-mvc',
#  'linux',
#  'sql-server',
#  'node.js',
#  'angularjs',
#  'django',
#  'performance',
#  'algorithm',
#  'string',
#  'xcode',
#  'arrays',
#  'wpf',
#  'eclipse',
#  'haskell',
#  'windows',
#  'scala',
#  'multithreading',
#  'json',
#  'c++11',
#  'regex',
#  'visual-studio',
#  'html5',
#  'osx',
#  'swift',
#  'database',
#  'unit-testing',
#  'spring',
#  'xml',
#  'bash',
#  'ajax',
#  'delphi',
#  'cocoa-touch',
#  'ruby-on-rails-3',
#  'visual-studio-2010',
#  'linq',
#  'debugging',
#  'generics',
#  'perl',
#  'entity-framework',
#  'mongodb',
#  'winforms',
#  'cocoa',
#  'security',
#  'postgresql',
#  'css3',
#  'templates',
#  'twitter-bootstrap',
#  'shell',
#  'list',
#  'google-chrome',
#  'vim',
#  'oop',
#  'image',
#  'hibernate',
#  'gcc',
#  'asp.net-mvc-3',
#  'facebook',
#  'oracle',
#  'rest',
#  'maven',
#  'http',
#  'exception',
#  'tsql',
#  'math',
#  'numpy',
#  'svn',
#  'qt',
#  'ipad',
#  'function',
#  'datetime',
#  'wcf',
#  'emacs',
#  'design-patterns',
#  'github',
#  'class',
#  'api',
#  'optimization',
#  'swing']

# %%
fig, ax = plt.subplots(figsize=(15, 10))
keywords.plot(100, cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
def most_common(tags):
    tags_filtered = []
    for i in range(0, len(tags)):
        if tags[i] in tags_features:
            tags_filtered.append(tags[i])
    return tags_filtered

# %%
new_df['Tags'] = new_df['Tags'].apply(lambda x: most_common(x))
new_df['Tags'] = new_df['Tags'].apply(lambda x: x if len(x)>0 else None)
# Out:
# <ipython-input-31-dd927834dc43>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Tags'] = new_df['Tags'].apply(lambda x: most_common(x))
# <ipython-input-31-dd927834dc43>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Tags'] = new_df['Tags'].apply(lambda x: x if len(x)>0 else None)

# %%
new_df.shape
# Out:
# (72950, 3)

# %%
new_df.dropna(subset=['Tags'], inplace=True)
# Out:
# <ipython-input-33-b044d0fc37c9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.dropna(subset=['Tags'], inplace=True)

# %%
new_df.shape
# Out:
# (63167, 3)

# %%
new_df['Body'] = new_df['Body'].apply(lambda x: BeautifulSoup(x).get_text())
# Out:
# <ipython-input-35-03b507505115>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Body'] = new_df['Body'].apply(lambda x: BeautifulSoup(x).get_text())

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r"what's", "what is ", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"can't", "can not ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r"\'scuse", " excuse ", text)
    text = re.sub(r"\'\n", " ", text)
    text = re.sub(r"\'\xa0", " ", text)
    text = re.sub('\s+', ' ', text)
    text = text.strip(' ')
    return text

# %%
new_df['Body'] = new_df['Body'].apply(lambda x: clean_text(x))
# Out:
# <ipython-input-37-8ad93794a984>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Body'] = new_df['Body'].apply(lambda x: clean_text(x))

# %%
token=ToktokTokenizer()

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
punct = '!"#$%&\'()*+,./:;<=>?@[\\]^_`{|}~'

# %%
def strip_list_noempty(mylist):
    newlist = (item.strip() if hasattr(item, 'strip') else item for item in mylist)
    return [item for item in newlist if item != '']

# %%
def clean_punct(text): 
    words=token.tokenize(text)
    punctuation_filtered = []
    regex = re.compile('[%s]' % re.escape(punct))
    remove_punctuation = str.maketrans(' ', ' ', punct)
    for w in words:
        if w in tags_features:
            punctuation_filtered.append(w)
        else:
            punctuation_filtered.append(regex.sub('', w))
  
    filtered_list = strip_list_noempty(punctuation_filtered)
        
    return ' '.join(map(str, filtered_list))

# %%
new_df['Body'] = new_df['Body'].apply(lambda x: clean_punct(x))
# Out:
# <ipython-input-43-77306190acc5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Body'] = new_df['Body'].apply(lambda x: clean_punct(x))

# %%
new_df['Body'][2]
# Out:
# 'has anyone got experience creating sql-based asp.net site-map providers i have got the default xml file websitemap working properly with my menu and sitemappath controls but i will need a way for the users of my site to create and modify pages dynamically i need to tie page viewing permissions into the standard asp.net membership system as well'

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
lemma=WordNetLemmatizer()
stop_words = set(stopwords.words("english"))

# %%
def lemitizeWords(text):
    words=token.tokenize(text)
    listLemma=[]
    for w in words:
        x=lemma.lemmatize(w, pos="v")
        listLemma.append(x)
    return ' '.join(map(str, listLemma))

def stopWordsRemove(text):
    
    stop_words = set(stopwords.words("english"))
    
    words=token.tokenize(text)
    
    filtered = [w for w in words if not w in stop_words]
    
    return ' '.join(map(str, filtered))

# %%
new_df['Body'] = new_df['Body'].apply(lambda x: lemitizeWords(x)) 
new_df['Body'] = new_df['Body'].apply(lambda x: stopWordsRemove(x))
# Out:
# <ipython-input-48-fc68fd460f45>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Body'] = new_df['Body'].apply(lambda x: lemitizeWords(x))
# <ipython-input-48-fc68fd460f45>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Body'] = new_df['Body'].apply(lambda x: stopWordsRemove(x))

# %%
new_df['Title'] = new_df['Title'].apply(lambda x: str(x))
new_df['Title'] = new_df['Title'].apply(lambda x: clean_text(x)) 
new_df['Title'] = new_df['Title'].apply(lambda x: clean_punct(x)) 
new_df['Title'] = new_df['Title'].apply(lambda x: lemitizeWords(x)) 
new_df['Title'] = new_df['Title'].apply(lambda x: stopWordsRemove(x))
# Out:
# <ipython-input-49-4683a26933e7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Title'] = new_df['Title'].apply(lambda x: str(x))
# <ipython-input-49-4683a26933e7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Title'] = new_df['Title'].apply(lambda x: clean_text(x))
# <ipython-input-49-4683a26933e7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Title'] = new_df['Title'].apply(lambda x: clean_punct(x))
# <ipython-input-49-4683a26933e7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Title'] = new_df['Title'].apply(lambda x: lemitizeWords(x))
# <ipython-input-49-4683a26933e7>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Title'] = new_df['Title'].apply(lambda x: stopWordsRemove(x))

# %%
no_topics = 20

# %%
text = new_df['Body']

# %%
vectorizer_train = TfidfVectorizer(analyzer = 'word',
                                       min_df=0.0,
                                       max_df = 1.0,
                                       strip_accents = None,
                                       encoding = 'utf-8', 
                                       preprocessor=None,
                                       token_pattern=r"(?u)\S\S+", # Need to repeat token pattern
                                       max_features=1000)

# %%
TF_IDF_matrix = vectorizer_train.fit_transform(text)

# %%
lda = LatentDirichletAllocation(n_components=no_topics, max_iter=5, learning_method='online', learning_offset=50,random_state=11).fit(TF_IDF_matrix)

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("--------------------------------------------")
        print("Topic %d:" % (topic_idx))
        print(" ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))
        print("--------------------------------------------")

no_top_words = 10
feature_names = vectorizer_train.get_feature_names_out()
display_topics(lda, feature_names, no_top_words)
# Out:
# --------------------------------------------
# Topic 0:
# div function var html script class page jquery id input
# --------------------------------------------
# --------------------------------------------
# Topic 1:
# use app ios would find xcode like know android application
# --------------------------------------------
# --------------------------------------------
# Topic 2:
# 00 scala font 09 01 02 tab utf-8 socket constant
# --------------------------------------------
# --------------------------------------------
# Topic 3:
# array list number data value would use like way function
# --------------------------------------------
# --------------------------------------------
# Topic 4:
# android width color height div background scroll style image top
# --------------------------------------------
# --------------------------------------------
# Topic 5:
# import python module modules def random filter statement docs 22
# --------------------------------------------
# --------------------------------------------
# Topic 6:
# button view android activity app event click menu item screen
# --------------------------------------------
# --------------------------------------------
# Topic 7:
# date datetime format 17 echo 00 time 15 convert year
# --------------------------------------------
# --------------------------------------------
# Topic 8:
# int public class return string void std type new foo
# --------------------------------------------
# --------------------------------------------
# Topic 9:
# file project error run use build command try install version
# --------------------------------------------
# --------------------------------------------
# Topic 10:
# table select query row column sql database id key value
# --------------------------------------------
# --------------------------------------------
# Topic 11:
# image json td tr cell label selector picture table img
# --------------------------------------------
# --------------------------------------------
# Topic 12:
# request server use error user file get url send connection
# --------------------------------------------
# --------------------------------------------
# Topic 13:
# rail gem ruby 12 11 14 pdf 13 10 18
# --------------------------------------------
# --------------------------------------------
# Topic 14:
# 124 string character line match node text file regex print
# --------------------------------------------
# --------------------------------------------
# Topic 15:
# git branch commit push repository merge github master remote pull
# --------------------------------------------
# --------------------------------------------
# Topic 16:
# controller class model view use name public property get object
# --------------------------------------------
# --------------------------------------------
# Topic 17:
# thread exception catch queue throw lock bitmap child wait exit
# --------------------------------------------
# --------------------------------------------
# Topic 18:
# nsstring nil animate animation self dictionary cursor yes hide iphone
# --------------------------------------------
# --------------------------------------------
# Topic 19:
# use would function memory code like question test time one
# --------------------------------------------

# %%
X1 = new_df['Body']
X2 = new_df['Title']
y = new_df['Tags']

# %%
multilabel_binarizer = MultiLabelBinarizer()
y_bin = multilabel_binarizer.fit_transform(y)

# %%
vectorizer_X1 = TfidfVectorizer(analyzer = 'word',
                                       min_df=0.0,
                                       max_df = 1.0,
                                       strip_accents = None,
                                       encoding = 'utf-8', 
                                       preprocessor=None,
                                       token_pattern=r"(?u)\S\S+",
                                       max_features=1000)

vectorizer_X2 = TfidfVectorizer(analyzer = 'word',
                                       min_df=0.0,
                                       max_df = 1.0,
                                       strip_accents = None,
                                       encoding = 'utf-8', 
                                       preprocessor=None,
                                       token_pattern=r"(?u)\S\S+",
                                       max_features=1000)

# %%
X1_tfidf = vectorizer_X1.fit_transform(X1)
X2_tfidf = vectorizer_X2.fit_transform(X2)

# %%
X_tfidf = hstack([X1_tfidf,X2_tfidf])

# %%
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y_bin, test_size = 0.2, random_state = 0) # Do 80/20 split

# %%
def avg_jacard(y_true,y_pred):
  
    jacard = np.minimum(y_true,y_pred).sum(axis=1) / np.maximum(y_true,y_pred).sum(axis=1)
    
    return jacard.mean()*100

def print_score(y_pred, clf):
    print("Clf: ", clf.__class__.__name__)
    print("Jacard score: {}".format(avg_jacard(y_test, y_pred)))
    print("Hamming loss: {}".format(hamming_loss(y_pred, y_test)*100))
    print("---")

# %%
dummy = DummyClassifier()
sgd = SGDClassifier()
lr = LogisticRegression()
mn = MultinomialNB()
svc = LinearSVC()
perceptron = Perceptron()
pac = PassiveAggressiveClassifier()

for classifier in [dummy, sgd, lr, mn, svc, perceptron, pac]:
    clf = OneVsRestClassifier(classifier)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print_score(y_pred, classifier)
# Out:
# Clf:  DummyClassifier
# Jacard score: 0.0
# Hamming loss: 1.5717112553427262
# ---
# Clf:  SGDClassifier
# Jacard score: 47.69273389267057
# Hamming loss: 0.9550419502928607
# ---
# Clf:  LogisticRegression
# Jacard score: 48.314468893462085
# Hamming loss: 0.9712680069653316
# ---
# Clf:  MultinomialNB
# Jacard score: 40.30181219234568
# Hamming loss: 1.1750039575747981
# ---
# Clf:  LinearSVC
# Jacard score: 52.356208115666725
# Hamming loss: 0.9552794047807505
# ---
# Clf:  Perceptron
# Jacard score: 46.88522530536143
# Hamming loss: 1.4487098306157986
# ---
# Clf:  PassiveAggressiveClassifier
# Jacard score: 49.43142842066382
# Hamming loss: 1.2679278138356813
# ---

# %%
mlpc = MLPClassifier()
mlpc.fit(X_train, y_train)

y_pred = mlpc.predict(X_test)

print_score(y_pred, mlpc)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Clf:  MLPClassifier
# Jacard score: 48.61684645363607
# Hamming loss: 1.339480766186481
# ---

# %%
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

y_pred = rfc.predict(X_test)

print_score(y_pred, rfc)
# Out:
# Clf:  RandomForestClassifier
# Jacard score: 45.27399609519287
# Hamming loss: 1.0140098147854995
# ---

# %%
param_grid = {'estimator__C':[1,10,100,1000]
              }

# %%
svc = OneVsRestClassifier(LinearSVC())
CV_svc = model_selection.GridSearchCV(estimator=svc, param_grid=param_grid, cv= 5, verbose=10, scoring=make_scorer(avg_jacard,greater_is_better=True))
CV_svc.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5; 1/4] START estimator__C=1..............................................
# [CV 1/5; 1/4] END ..............estimator__C=1;, score=52.335 total time=  18.3s
# [CV 2/5; 1/4] START estimator__C=1..............................................
# [CV 2/5; 1/4] END ..............estimator__C=1;, score=52.115 total time=  15.1s
# [CV 3/5; 1/4] START estimator__C=1..............................................
# [CV 3/5; 1/4] END ..............estimator__C=1;, score=51.207 total time=  15.3s
# [CV 4/5; 1/4] START estimator__C=1..............................................
# [CV 4/5; 1/4] END ..............estimator__C=1;, score=50.967 total time=  14.7s
# [CV 5/5; 1/4] START estimator__C=1..............................................
# [CV 5/5; 1/4] END ..............estimator__C=1;, score=51.546 total time=  15.1s
# [CV 1/5; 2/4] START estimator__C=10.............................................
# [CV 1/5; 2/4] END .............estimator__C=10;, score=48.658 total time=  43.3s
# [CV 2/5; 2/4] START estimator__C=10.............................................
# [CV 2/5; 2/4] END .............estimator__C=10;, score=48.319 total time=  45.9s
# [CV 3/5; 2/4] START estimator__C=10.............................................
# [CV 3/5; 2/4] END .............estimator__C=10;, score=47.885 total time=  44.8s
# [CV 4/5; 2/4] START estimator__C=10.............................................
# [CV 4/5; 2/4] END .............estimator__C=10;, score=46.934 total time=  44.2s
# [CV 5/5; 2/4] START estimator__C=10.............................................
# [CV 5/5; 2/4] END .............estimator__C=10;, score=47.594 total time=  47.2s
# [CV 1/5; 3/4] START estimator__C=100............................................
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5; 3/4] END ............estimator__C=100;, score=44.843 total time= 1.2min
# [CV 2/5; 3/4] START estimator__C=100............................................
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5; 3/4] END ............estimator__C=100;, score=44.714 total time= 1.2min
# [CV 3/5; 3/4] START estimator__C=100............................................
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5; 3/4] END ............estimator__C=100;, score=44.281 total time= 1.3min
# [CV 4/5; 3/4] START estimator__C=100............................................
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5; 3/4] END ............estimator__C=100;, score=43.676 total time= 1.3min
# [CV 5/5; 3/4] START estimator__C=100............................................
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5; 4/4] END ...........estimator__C=1000;, score=41.306 total time= 1.4min
# [CV 5/5; 4/4] START estimator__C=1000...........................................
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5; 4/4] END ...........estimator__C=1000;, score=42.190 total time= 1.4min
# GridSearchCV(cv=5, estimator=OneVsRestClassifier(estimator=LinearSVC()),
#              param_grid={'estimator__C': [1, 10, 100, 1000]},
#              scoring=make_scorer(avg_jacard), verbose=10)

# %%
CV_svc.best_params_
# Out:
# {'estimator__C': 1}

# %%
best_model = CV_svc.best_estimator_

# %%
y_pred = best_model.predict(X_test)

print_score(y_pred, best_model)
# Out:
# Clf:  OneVsRestClassifier
# Jacard score: 52.356208115666725
# Hamming loss: 0.9552794047807505
# ---

# %%
for i in range(y_train.shape[1]):
    print(multilabel_binarizer.classes_[i])
    print(confusion_matrix(y_test[:,i], y_pred[:,i]))
    print("")
# Out:
# .net
# [[12033    54]
#  [  447   100]]
#
# ajax
# [[12526    15]
#  [   55    38]]
#
# algorithm
# [[12445    21]
#  [   87    81]]
#
# android
# [[11528    40]
#  [  194   872]]
#
# angularjs
# [[12443     7]
#  [   49   135]]
#
# api
# [[12567    14]
#  [   45     8]]
#
# arrays
# [[12405    55]
#  [  103    71]]
#
# asp.net
# [[12346    30]
#  [  166    92]]
#
# asp.net-mvc
# [[12402    41]
#  [   99    92]]
#
# asp.net-mvc-3
# [[12566    11]
#  [   44    13]]
#
# bash
# [[12520     7]
#  [   46    61]]
#
# c
# [[12220    58]
#  [  203   153]]
#
# c#
# [[11060   175]
#  [  618   781]]
#
# c++
# [[11674    91]
#  [  260   609]]
#
# c++11
# [[12453    31]
#  [  103    47]]
#
# class
# [[12574    12]
#  [   45     3]]
#
# cocoa
# [[12553     4]
#  [   69     8]]
#
# cocoa-touch
# [[12530    10]
#  [   90     4]]
#
# css
# [[12186    74]
#  [  123   251]]
#
# css3
# [[12561    13]
#  [   45    15]]
#
# database
# [[12503    29]
#  [   84    18]]
#
# datetime
# [[12571    17]
#  [   36    10]]
#
# debugging
# [[12523    27]
#  [   50    34]]
#
# delphi
# [[12542     2]
#  [   39    51]]
#
# design-patterns
# [[12573    11]
#  [   36    14]]
#
# django
# [[12465     7]
#  [   31   131]]
#
# eclipse
# [[12472     9]
#  [   55    98]]
#
# emacs
# [[12591     1]
#  [   16    26]]
#
# entity-framework
# [[12547    20]
#  [   36    31]]
#
# exception
# [[12551    17]
#  [   43    23]]
#
# facebook
# [[12571     9]
#  [   17    37]]
#
# function
# [[12576    11]
#  [   44     3]]
#
# gcc
# [[12566    12]
#  [   35    21]]
#
# generics
# [[12558     9]
#  [   31    36]]
#
# git
# [[12425     8]
#  [   17   184]]
#
# github
# [[12575     5]
#  [   23    31]]
#
# google-chrome
# [[12559     8]
#  [   33    34]]
#
# haskell
# [[12497     5]
#  [   70    62]]
#
# hibernate
# [[12570     5]
#  [   16    43]]
#
# html
# [[12109   102]
#  [  261   162]]
#
# html5
# [[12506     7]
#  [   77    44]]
#
# http
# [[12563    14]
#  [   41    16]]
#
# image
# [[12561    15]
#  [   50     8]]
#
# ios
# [[12001    93]
#  [  283   257]]
#
# ipad
# [[12573     2]
#  [   42    17]]
#
# iphone
# [[12227    49]
#  [  246   112]]
#
# java
# [[11130   144]
#  [  565   795]]
#
# javascript
# [[11338   168]
#  [  511   617]]
#
# jquery
# [[12011    65]
#  [  199   359]]
#
# json
# [[12474    24]
#  [   65    71]]
#
# linq
# [[12536    14]
#  [   37    47]]
#
# linux
# [[12420    27]
#  [  121    66]]
#
# list
# [[12540    19]
#  [   61    14]]
#
# math
# [[12577    10]
#  [   46     1]]
#
# maven
# [[12563    15]
#  [   15    41]]
#
# mongodb
# [[12569     1]
#  [   33    31]]
#
# multithreading
# [[12468    25]
#  [   85    56]]
#
# mysql
# [[12363    32]
#  [   74   165]]
#
# node.js
# [[12446    13]
#  [   71   104]]
#
# numpy
# [[12579     4]
#  [   26    25]]
#
# objective-c
# [[12199    81]
#  [  249   105]]
#
# oop
# [[12573     5]
#  [   56     0]]
#
# optimization
# [[12584     4]
#  [   46     0]]
#
# oracle
# [[12576     3]
#  [   25    30]]
#
# osx
# [[12493    15]
#  [   88    38]]
#
# performance
# [[12437    29]
#  [  133    35]]
#
# perl
# [[12563     0]
#  [   27    44]]
#
# php
# [[12001    38]
#  [  218   377]]
#
# postgresql
# [[12572     0]
#  [   29    33]]
#
# python
# [[11715    51]
#  [  240   628]]
#
# qt
# [[12585     2]
#  [   24    23]]
#
# r
# [[12384    31]
#  [   97   122]]
#
# regex
# [[12499    10]
#  [   41    84]]
#
# rest
# [[12565     9]
#  [   30    30]]
#
# ruby
# [[12311    36]
#  [  158   129]]
#
# ruby-on-rails
# [[12304    41]
#  [  105   184]]
#
# ruby-on-rails-3
# [[12526    21]
#  [   75    12]]
#
# scala
# [[12488     7]
#  [   36   103]]
#
# security
# [[12564     9]
#  [   44    17]]
#
# shell
# [[12554    13]
#  [   43    24]]
#
# spring
# [[12516    15]
#  [   35    68]]
#
# sql
# [[12269    70]
#  [  158   137]]
#
# sql-server
# [[12390    50]
#  [   98    96]]
#
# string
# [[12432    54]
#  [   93    55]]
#
# svn
# [[12586     6]
#  [   12    30]]
#
# swift
# [[12521     5]
#  [   35    73]]
#
# swing
# [[12582     2]
#  [   28    22]]
#
# templates
# [[12542    13]
#  [   44    35]]
#
# tsql
# [[12562    16]
#  [   52     4]]
#
# twitter-bootstrap
# [[12565     2]
#  [   21    46]]
#
# unit-testing
# [[12478    28]
#  [   70    58]]
#
# vim
# [[12571     2]
#  [   15    46]]
#
# visual-studio
# [[12497    29]
#  [   72    36]]
#
# visual-studio-2010
# [[12542    17]
#  [   52    23]]
#
# wcf
# [[12583     0]
#  [   12    39]]
#
# windows
# [[12454    30]
#  [  112    38]]
#
# winforms
# [[12556    14]
#  [   42    22]]
#
# wpf
# [[12463     8]
#  [   55   108]]
#
# xcode
# [[12426    26]
#  [  102    80]]
#
# xml
# [[12507    17]
#  [   58    52]]

# %%
def print_top10(feature_names, clf, class_labels):
    """Prints features with the highest coefficient values, per class"""
    if isinstance(clf, OneVsRestClassifier):
        classifiers = clf.estimators_
    else:
        classifiers = [clf]
    
    for i, class_label in enumerate(multilabel_binarizer.classes_):
      classifier = best_model.estimators_[i]
      if hasattr(classifier, 'coef_'):
        coefficients = classifier.coef_
        top10 = np.argsort(coefficients[0])[-10:]
        top_words = [feature_names[j] for j in top10 if j < len(feature_names)]
        print("--------------------------------------------")
        print("%s: %s" % (class_label, " ".join(top_words)))

# %%
feature_names = vectorizer_X1.get_feature_names_out() + vectorizer_X2.get_feature_names_out()

# %%
print_top10(feature_names, best_model, multilabel_binarizer.classes_)
# Out:
# --------------------------------------------
# .net: determinedocument finallyfragment senderscale windowswebview assemblyboost microsoftmock consolewritelinecurl .net100
# --------------------------------------------
# ajax: muchmove imginitialize requestremote webvs itemsitem securityrun loadlinux ajaxarray
# --------------------------------------------
# algorithm: logload inputinstead additionalarea sticksqlalchemy giveheight althoughattribute problemprimary algorithmassembly
# --------------------------------------------
# android: eandroidruntimeempty linearlayoutlibrary fragmentgo intentinterfaces textviewtag activityapplication androidautocomplete
# --------------------------------------------
# angularjs: resourcerepeat tokentheme configcould controllerday scoperotate
# --------------------------------------------
# api: virtualversus interfaceinternet retrieverequest dealdevelop docseditor dependencydirective apibar
# --------------------------------------------
# arrays: particularparent restreport successstill usernameupdate comecontain arrayblank
# --------------------------------------------
# asp.net: tracetitle websitewait controldatetime serverscript asp.netboolean
# --------------------------------------------
# asp.net-mvc: trytransaction ieinherit inheritinstal providerproper actionappear viewversions mvcmust
# --------------------------------------------
# asp.net-mvc-3: usunicode insteadintellij preferport descriptiondisplay successfullystl sideselection downloadefficiently viewversions
# --------------------------------------------
# bash: shortseem locallist homeiis 21advantage 22affect variablesvalidate syntaxstyle scriptrout echoencode
# --------------------------------------------
# c: relevantreflection sizeofset definedialog charcompiler structstatement embederror gcchandler printfpress
# --------------------------------------------
# c#: datetimedesign remainrefresh senderscale typeoftrue foreachgithub consolewritelinecurl c#cocoa
# --------------------------------------------
# c++: boostcharacter coutdefinition stdspring c++cod
# --------------------------------------------
# c++11: obviouslyopen initializeinstallation standardspace viavector stdspring templatesyntax movemonth autobrowsers
# --------------------------------------------
# class: thingtarget wheneverwarn outsideoutside nextnext quitepure coutdefinition
# --------------------------------------------
# cocoa: windowwebsite lastkey notificationnumpy launchkill superstrange 21advantage easilyemulator nslogobject maclose
# --------------------------------------------
# cocoa-touch: amountauthentication animationautomatically severalsecure validateusage longerlog
# --------------------------------------------
# css: tracetitle sticksqlalchemy overrideoverflow coupledefault webvs lesslayer fixgcc cssdelete
# --------------------------------------------
# css3: waysvoid mustmultiple transformtomcat 50android selectorsample
# --------------------------------------------
# database: msmouse configurationcount resolverender databasedeprecate
# --------------------------------------------
# datetime: reasonrail 092012 providerproper exexpressions behaviorcancel wonderwidth preferport originaloriginal datetimedesign
# --------------------------------------------
# debugging: supposestring bugclear attachbottom debugdeveloper
# --------------------------------------------
# delphi: samplerestful unitubuntu oldoperations 2010admin finallyfragment componentcore endevaluate begincamera procedureprivate
# --------------------------------------------
# design-patterns: thinktell developerdom specificallyslow usefulunix designdiv cleanconfiguration patternpartial
# --------------------------------------------
# django: instalintegers playphonegap textjavascripttabs placepermissions adminarguments modelmodule djangoeclipse
# --------------------------------------------
# eclipse: propertiesprogress othersosx problemprimary softwareshare eclipseend
# --------------------------------------------
# emacs: searchrspec enableescape recentlyrange behaviourcannot configurecpu 24algorithm modemodify nilnode bufferclause
# --------------------------------------------
# entity-framework: contextdatatable propertyproject applybehaviour dbdetermine firstgame entityexample frameworkgoogle
# --------------------------------------------
# exception: insteadintellij wowidget validateusage insertint kindjson senseschema exceptionextract exceptionsfacebook
# --------------------------------------------
# facebook: confusecrash postpointer sdkrow callbackcollections askbody effectenter facebookfinish
# --------------------------------------------
# function: boolchange 24algorithm functiongroup enoughevents
# --------------------------------------------
# gcc: enableescape targetswift tutorialtransition marginmany 32alternative declaredevice gcchandler
# --------------------------------------------
# generics: typeoftrue progressprofile othersosx recentlyrange extendfile viavector generichaskell
# --------------------------------------------
# git: locallist commitcontext mastermark branchchoose githeaders
# --------------------------------------------
# github: bundleclient accessanonymous pushprotocol upgradeunable githubheap
# --------------------------------------------
# google-chrome: hrefimplementation insteadintellij problemsprint chromeconditional
# --------------------------------------------
# haskell: boolchange perhapspdf derivedirectory typetrigger xswrite languagekeep appendbasic maybemember instanceintegration
# --------------------------------------------
# hibernate: retrieverequest generatehash nothingnull entityexample fetchfolder sessionsdk transactiontoken
# --------------------------------------------
# html: finallyfragment tdswitch alongasync fixgcc elementsenvironment onclickoperator htmlimplicit
# --------------------------------------------
# html5: progressprofile properprogramatically browsercircle mainmachine
# --------------------------------------------
# http: enableescape clientconnect parampad jsjoin functionalitygui requestremote largekernel httpimport
# --------------------------------------------
# image: onclickoperator aroundbitmap confusecrash imageinitialization yesxcode imginitialize pictureperl
# --------------------------------------------
# ios: nslogobject delegatediff uitry dueelse appbase allocassign applebatch iosip
# --------------------------------------------
# ipad: finishfree orientationorientation waysvoid elseequal detaildjango lesslayer hardhttp
# --------------------------------------------
# iphone: ratherqt coredebug releasereference delegatediff iphoneipad
# --------------------------------------------
# java: finalforward jaritems extendfile systemoutprintlnsubversion javaiterate
# --------------------------------------------
# javascript: chromeconditional onclickoperator undefinedtwice consolelogcsv varusers jsjoin javascriptjar
# --------------------------------------------
# jquery: completecookie clickconflict pluginplace ajaxarray readyquestion jqueryjob
# --------------------------------------------
# json: descriptiondisplay callbackcollections retrieverequest anythingbackground fieldfollow jsonjpa
# --------------------------------------------
# linq: inheritinstal collectionconstant sourcesingle expressionfield codconsole varusers wellwant
# --------------------------------------------
# linux: setupsection fillforeign editengine processproblem childcomponent statespecific psproperly linuxlimit
# --------------------------------------------
# list: severalsecure -110 ratherqt bigcast listline
# --------------------------------------------
# math: computercorrect holdignore uniquetype hitiframe logload calculatecodeigniter logiclocal fastfix assumeborder
# --------------------------------------------
# maven: infoinsert easyenable yesxcode dependencydirective modulesmonitor advancearound executionfail mavenmax
# --------------------------------------------
# mongodb: thustest shellsee errexecution dbdetermine cursordependencies documentedittext collectionconstant
# --------------------------------------------
# multithreading: completelycoordinate suggestionsstorage 10030 solveshow preventpostgres completecookie separatescope locklive threadtemplates
# --------------------------------------------
# mysql: usunicode usersupgrade 24algorithm limitlevel databasedeprecate rootresize perpassword tracktogether mysqlmvc
# --------------------------------------------
# node.js: schemaroot âzoom requireremove nodenode.js errexecution
# --------------------------------------------
# numpy: insteadintellij ignoreinheritance importinjection matrixmatrix arrayblank fixgcc farfit
# --------------------------------------------
# objective-c: exceptionsfacebook iosip selectorsample textjavascripttabs superstrange nsstringobjective nslogobject
# --------------------------------------------
# oop: directlydrop objectonclick finishfree coupledefault classconfig obviousone fitgarbage referreason designdiv
# --------------------------------------------
# optimization: siteservice 052010 compilerconvert fasterflask coupledefault
# --------------------------------------------
# oracle: schemaroot numberoccur featurefloat endevaluate developerdom replacerelationship begincamera
# --------------------------------------------
# osx: notificationnumpy setupsection applebatch osos maclose
# --------------------------------------------
# performance: importantinline entireexactly waysvoid fasterflask slowsettings performancepattern
# --------------------------------------------
# perl: lesslayer tracetitle printprefix scriptrout warnvisible foreachgithub fetchfolder
# --------------------------------------------
# php: modulesmonitor constructcustom foreachgithub protectpromise echoencode arrayblank phpperformance
# --------------------------------------------
# postgresql: peoplepass muchmove severalsecure docseditor databasedeprecate surestruct
# --------------------------------------------
# python: importinjection defdevices pythonprovider
# --------------------------------------------
# qt: effectenter coulddeclaration connectcreate parentparallel pictureperl actuallyapply developdocumentation
# --------------------------------------------
# r: variablesvalidate framegood vectorvalue functiongroup librarylength packageoverload namvc3 plotpip
# --------------------------------------------
# regex: eitherentity 17activerecord operationoptimize replacerelationship severalsecure matchmatch regularredirect regexrecord
# --------------------------------------------
# rest: multiplemuch anythingbackground entityexample servicescroll senseschema produceproblems restreport
# --------------------------------------------
# ruby: unfortunatelytwo longerlog putprovide bundleclient endevaluate rubyresource
# --------------------------------------------
# ruby-on-rails: configcould productionprocess renderregular modelmodule endevaluate railpurpose
# --------------------------------------------
# ruby-on-rails-3: configcould originaloriginal 27allow coupledefault deploydirectly railpurpose
# --------------------------------------------
# scala: transformtomcat casecolumns extendfile equalexclude defdevices valurl scalareturn
# --------------------------------------------
# security: certificatecompilation everythingexpression providerproper softwareshare securityrun
# --------------------------------------------
# shell: sortsimulator correctdebugger thingtarget 22affect parentparallel attachbottom shellsee
# --------------------------------------------
# spring: finalforward nestneed brchild primarypractice infoinsert beancall springsolve
# --------------------------------------------
# sql: topthrow systemsubmit varcharutf-8 infoinsert selectsafe productionprocess sqlsomething
# --------------------------------------------
# sql-server: selectsafe procedureprivate sqlsomething recommendraw transactiontoken varcharutf-8 studiostatic serverscript
# --------------------------------------------
# string: remainrefresh largekernel assignbootstrap tabsum stringstate
# --------------------------------------------
# svn: fineframework sitserver askbody commitcontext repositoryrelease svnstructure
# --------------------------------------------
# swift: awarebundle developerdom activeappend initinstall varusers funcgrid letlayout
# --------------------------------------------
# swing: alsoattach practicepointers confusecrash feelfocus yetxml framegood newnew componentcore
# --------------------------------------------
# templates: typetrigger dealdevelop declaredevice articleblock dropelements simplesend templatesyntax
# --------------------------------------------
# tsql: statementspecify 32alternative createdelegate interestinternal transactiontoken equalexclude realqueue alreadyasynchronous topthrow
# --------------------------------------------
# twitter-bootstrap: browsercircle importantinline renderregular classconfig lesslayer
# --------------------------------------------
# unit-testing: letlayout severalsecure troubletouch thingstask anybodyazure unitubuntu testtab
# --------------------------------------------
# vim: visualvia letlayout bettercase modifymodules modemodify stacksource pluginplace switchstudio somewheresimulate
# --------------------------------------------
# visual-studio: pointerplay wheneverwarn debugdeveloper studiostatic bigcast visualvia vsview
# --------------------------------------------
# visual-studio-2010: greathighlight anywaybad presspossible hitiframe 45amp definitiondictionary 2010admin
# --------------------------------------------
# wcf: reasonrail securityrun layerknow softwareshare bindcause servicescroll
# --------------------------------------------
# windows: dlledit windowswebview
# --------------------------------------------
# winforms: successstill windowswebview controldatetime formgive closeconnection
# --------------------------------------------
# wpf: raisepush resourcerepeat childcomponent controldatetime propertyproject visualvia xmlnswrap uitry bindcause
# --------------------------------------------
# xcode: bundleclient logiclocal targetswift frameworkgoogle profileproduce xcodewould
# --------------------------------------------
# xml: cleanconfiguration applebatch microsoftmock tutorialtransition templatesyntax xswrite layoutwidthlanguage xmlwpf

# %%
import joblib 
joblib_file = "tagPredictor.pkl" 
joblib.dump(best_model, joblib_file)
# Out:
# ['tagPredictor.pkl']
